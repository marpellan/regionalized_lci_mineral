# %%
import pandas as pd
import numpy as np

# %% [markdown]
# The methodology follows 4 main steps:
# - 1) Import production data per facility previously collected
# - 2) Import, clean and harmonize environmental data, which typically include Supply-Use-Tables (SUT), National Pollutant Inventory, GHG from large facilities and satellite data.
# - 3) Normalize the emissions per facility by the production
# - 4) Create consumption market by weighting the normalized emissions per facility based on the market share by facility

# %% [markdown]
# # 1 - Import production data per facility

# %% [markdown]
# # 2 - Import, clean and harmonize environmental data

# %% [markdown]
# ## 2.1 Import and clean

# %% [markdown]
# ### 2.1.1 NPRI

# %% [markdown]
# #### Create mapping NPRI-EI through IW+ mapping

# %%
# Import existing concordances 
mapping_npri_iw = pd.read_excel(r'data/Concordances/openIO_IW_EI_concordance.xlsx', sheet_name='NPRI_to_IW21')
mapping_ei_iw = pd.read_excel(r'data/Concordances/openIO_IW_EI_concordance.xlsx', sheet_name='EI_to_IW+')

# %%
# Standardize column names for merging
mapping_npri_iw.rename(columns={'IMPACT World+ flows': 'iw_name'}, inplace=True)
mapping_ei_iw.rename(columns={'iw name': 'iw_name'}, inplace=True)

# %%
# Add the 'EI' column to df_npri_iw based on matching iw_name with df_ei_iw
mapping_npri_iw['EI'] = mapping_npri_iw['iw_name'].map(
    lambda iw: mapping_ei_iw[mapping_ei_iw['iw_name'] == iw]['ecoinvent name'].iloc[0]
    if iw in mapping_ei_iw['iw_name'].values else 'No match found'
)

# %%
mapping_npri_iw
# Out:
#               OpenIO flows                        iw_name  \
# 0           Carbon dioxide         Carbon dioxide, fossil
# 1                  Methane                Methane, fossil
# 2      Dinitrogen monoxide            Dinitrogen monoxide
# 3                      CF4  Methane, tetrafluoro-, CFC-14
# 4                     C2F6   Ethane, hexafluoro-, HFC-116
# ..                     ...                            ...
# 348        Propylene oxide                Propylene oxide
# 349               Thiourea                       Thiourea
# 350  2-Ethoxyethyl acetate          2-Ethoxyethyl acetate
# 351      Azo disperse dyes                            NaN
# 352        Propionaldehyde                       Propanal
#
#                                EI
# 0          Carbon dioxide, fossil
# 1                         Methane
# 2             Dinitrogen monoxide
# 3     Methane, tetrafluoro-, R-14
# 4    Ethane, hexafluoro-, HFC-116
# ..                            ...
# 348               Propylene oxide
# 349                No match found
# 350                No match found
# 351                No match found
# 352                      Propanal
#
# [353 rows x 3 columns]

# %%
#mapping_npri_iw.to_excel(r'data/Concordances/NPRI_EI_concordance.xlsx', index=False)

# %% [markdown]
# #### Import and sort NPRI data

# %%
npri_df = pd.read_excel(r'data/Emissions_accounts/Raw_data/NPRI/NPRI-INRP_DataDonnées_2023.xlsx', sheet_name='INRP-NPRI 2023', skiprows=3)

# %%
npri_df
# Out:
#        Year  NPRI ID                                       Company Name  \
# 0      2023    30809  •\tEmboutissage Takumi Canada Inc./Takumi Stam...
# 1      2023    30809  •\tEmboutissage Takumi Canada Inc./Takumi Stam...
# 2      2023    30809  •\tEmboutissage Takumi Canada Inc./Takumi Stam...
# 3      2023    30809  •\tEmboutissage Takumi Canada Inc./Takumi Stam...
# 4      2023    30809  •\tEmboutissage Takumi Canada Inc./Takumi Stam...
# ...     ...      ...                                                ...
# 63869  2023    34009                                  ZF Group Oakville
# 63870  2023     7095                                         Zochem ULC
# 63871  2023     7095                                         Zochem ULC
# 63872  2023     7095                                         Zochem ULC
# 63873  2023     7095                                         Zochem ULC
#
#                     Facility Name        City         CSD CA or CMA  \
# 0      Takumi Stamping St. Thomas  St. Thomas  St. Thomas    London
# 1      Takumi Stamping St. Thomas  St. Thomas  St. Thomas    London
# 2      Takumi Stamping St. Thomas  St. Thomas  St. Thomas    London
# 3      Takumi Stamping St. Thomas  St. Thomas  St. Thomas    London
# 4      Takumi Stamping St. Thomas  St. Thomas  St. Thomas    London
# ...                           ...         ...         ...       ...
# 63869           ZF Group Oakville    Oakville    Oakville   Toronto
# 63870                      Zochem    Brampton    Brampton   Toronto
# 63871                      Zochem    Brampton    Brampton   Toronto
# 63872                      Zochem    Brampton    Brampton   Toronto
# 63873                      Zochem    Brampton    Brampton   Toronto
#
#       Economic Region Province Postal Code  ... Organic Compound Recovery  \
# 0              London       ON     N5P 0B6  ...                       NaN
# 1              London       ON     N5P 0B6  ...                       NaN
# 2              London       ON     N5P 0B6  ...                       NaN
# 3              London       ON     N5P 0B6  ...                       NaN
# 4              London       ON     N5P 0B6  ...                       NaN
# ...               ...      ...         ...  ...                       ...
# 63869         Toronto       ON         NaN  ...                       NaN
# 63870         Toronto       ON     L6T 3T4  ...                       NaN
# 63871         Toronto       ON     L6T 3T4  ...                       NaN
# 63872         Toronto       ON     L6T 3T4  ...                       NaN
# 63873         Toronto       ON     L6T 3T4  ...                       NaN
#
#       Metal Recovery Inorganic Compound Recovery Acid or Base Recovery  \
# 0                NaN                         NaN                   NaN
# 1                NaN                         NaN                   NaN
# 2                NaN                         NaN                   NaN
# 3                NaN                         NaN                   NaN
# 4                NaN                         NaN                   NaN
# ...              ...                         ...                   ...
# 63869            NaN                         NaN                   NaN
# 63870            NaN                         NaN                   NaN
# 63871            NaN                         NaN                   NaN
# 63872            NaN                         NaN                   NaN
# 63873         275.02                         NaN                   NaN
#
#        Catalyst Recovery  Pollution Abatement Residue Recovery  \
# 0                    NaN                                   NaN
# 1                    NaN                                   NaN
# 2                    NaN                                   NaN
# 3                    NaN                                   NaN
# 4                    NaN                                   NaN
# ...                  ...                                   ...
# 63869                NaN                                   NaN
# 63870                NaN                                   NaN
# 63871                NaN                                   NaN
# 63872                NaN                                   NaN
# 63873                NaN                                   NaN
#
#        Used Oil Recovery Other.2 Total.5  \
# 0                    NaN     NaN     NaN
# 1                    NaN     NaN     NaN
# 2                    NaN     NaN     NaN
# 3                    NaN     NaN     NaN
# 4                    NaN     NaN     NaN
# ...                  ...     ...     ...
# 63869                NaN     NaN     NaN
# 63870                NaN     NaN     NaN
# 63871                NaN     NaN     NaN
# 63872                NaN     NaN     NaN
# 63873                NaN     NaN  275.02
#
#        Total Releases, Disposals and Transfers for Recycling
# 0                                               0.000020
# 1                                               0.004000
# 2                                               0.097000
# 3                                               0.000090
# 4                                               0.000000
# ...                                                  ...
# 63869                                          12.735000
# 63870                                           0.356000
# 63871                                           0.356000
# 63872                                           0.356000
# 63873                                         275.525753
#
# [63874 rows x 77 columns]

# %%
# We need to rename it to merge it to NPRI data
mapping_npri_iw.rename(columns={'OpenIO flows': 'Substance Name (English)'}, inplace=True)

# %%
# We add the Ecoinvent name based on the mapping 
npri_df = npri_df.merge(mapping_npri_iw[['Substance Name (English)', 'EI']],
              on='Substance Name (English)',
              how='left')

# %%
npri_df
# Out:
#        Year  NPRI ID                                       Company Name  \
# 0      2023    30809  •\tEmboutissage Takumi Canada Inc./Takumi Stam...
# 1      2023    30809  •\tEmboutissage Takumi Canada Inc./Takumi Stam...
# 2      2023    30809  •\tEmboutissage Takumi Canada Inc./Takumi Stam...
# 3      2023    30809  •\tEmboutissage Takumi Canada Inc./Takumi Stam...
# 4      2023    30809  •\tEmboutissage Takumi Canada Inc./Takumi Stam...
# ...     ...      ...                                                ...
# 63869  2023    34009                                  ZF Group Oakville
# 63870  2023     7095                                         Zochem ULC
# 63871  2023     7095                                         Zochem ULC
# 63872  2023     7095                                         Zochem ULC
# 63873  2023     7095                                         Zochem ULC
#
#                     Facility Name        City         CSD CA or CMA  \
# 0      Takumi Stamping St. Thomas  St. Thomas  St. Thomas    London
# 1      Takumi Stamping St. Thomas  St. Thomas  St. Thomas    London
# 2      Takumi Stamping St. Thomas  St. Thomas  St. Thomas    London
# 3      Takumi Stamping St. Thomas  St. Thomas  St. Thomas    London
# 4      Takumi Stamping St. Thomas  St. Thomas  St. Thomas    London
# ...                           ...         ...         ...       ...
# 63869           ZF Group Oakville    Oakville    Oakville   Toronto
# 63870                      Zochem    Brampton    Brampton   Toronto
# 63871                      Zochem    Brampton    Brampton   Toronto
# 63872                      Zochem    Brampton    Brampton   Toronto
# 63873                      Zochem    Brampton    Brampton   Toronto
#
#       Economic Region Province Postal Code  ... Metal Recovery  \
# 0              London       ON     N5P 0B6  ...            NaN
# 1              London       ON     N5P 0B6  ...            NaN
# 2              London       ON     N5P 0B6  ...            NaN
# 3              London       ON     N5P 0B6  ...            NaN
# 4              London       ON     N5P 0B6  ...            NaN
# ...               ...      ...         ...  ...            ...
# 63869         Toronto       ON         NaN  ...            NaN
# 63870         Toronto       ON     L6T 3T4  ...            NaN
# 63871         Toronto       ON     L6T 3T4  ...            NaN
# 63872         Toronto       ON     L6T 3T4  ...            NaN
# 63873         Toronto       ON     L6T 3T4  ...         275.02
#
#       Inorganic Compound Recovery Acid or Base Recovery Catalyst Recovery  \
# 0                             NaN                   NaN               NaN
# 1                             NaN                   NaN               NaN
# 2                             NaN                   NaN               NaN
# 3                             NaN                   NaN               NaN
# 4                             NaN                   NaN               NaN
# ...                           ...                   ...               ...
# 63869                         NaN                   NaN               NaN
# 63870                         NaN                   NaN               NaN
# 63871                         NaN                   NaN               NaN
# 63872                         NaN                   NaN               NaN
# 63873                         NaN                   NaN               NaN
#
#        Pollution Abatement Residue Recovery  Used Oil Recovery  Other.2  \
# 0                                       NaN                NaN      NaN
# 1                                       NaN                NaN      NaN
# 2                                       NaN                NaN      NaN
# 3                                       NaN                NaN      NaN
# 4                                       NaN                NaN      NaN
# ...                                     ...                ...      ...
# 63869                                   NaN                NaN      NaN
# 63870                                   NaN                NaN      NaN
# 63871                                   NaN                NaN      NaN
# 63872                                   NaN                NaN      NaN
# 63873                                   NaN                NaN      NaN
#
#       Total.5 Total Releases, Disposals and Transfers for Recycling  \
# 0         NaN                                           0.000020
# 1         NaN                                           0.004000
# 2         NaN                                           0.097000
# 3         NaN                                           0.000090
# 4         NaN                                           0.000000
# ...       ...                                                ...
# 63869     NaN                                          12.735000
# 63870     NaN                                           0.356000
# 63871     NaN                                           0.356000
# 63872     NaN                                           0.356000
# 63873  275.02                                         275.525753
#
#                             EI
# 0                     Acrolein
# 1                      Ammonia
# 2      Carbon monoxide, fossil
# 3                 Formaldehyde
# 4                    Manganese
# ...                        ...
# 63869                      NaN
# 63870           No match found
# 63871   Particulates, < 2.5 um
# 63872           No match found
# 63873                     Zinc
#
# [63874 rows x 78 columns]

# %%
metal_mining_df = npri_df[npri_df['NAICS 4 Sector Name (English)'] == 'Metal ore mining']
metal_manufacturing_df = npri_df[npri_df["NAICS 4 Code"].astype(str).str[:3] == "331"]

# %%
# To see how much NPRI substances do not found a match in Ecoinvent 
print((metal_mining_df['EI'].eq('No match found').mean() * 100)) 
print((metal_manufacturing_df['EI'].eq('No match found').mean() * 100))
# Out:
# 16.16945107398568
# 21.282327586206897

# %% [markdown]
# So respectively 86% and 79% of the substances for the metal ore mining and primary metal manufacturing are matched

# %%
# To have the main information and get a template for site-specific data
recap_metal_mining_df = metal_mining_df[['NPRI ID', 'Company Name', 'Facility Name', 'City', 
 'CSD', 'Province', 
 'Latitude', 'Longitude', 
 'NAICS 4 Sector Name (English)', 'NAICS 4 Code', 
'NAICS 6 Sector Name (English)', 'NAICS 6 Code']].drop_duplicates()

# %%
# To have the main information and get a template for site-specific data
recap_metal_manufacturing_df = metal_manufacturing_df[['NPRI ID', 'Company Name', 'Facility Name', 'City', 
 'CSD', 'Province', 
 'Latitude', 'Longitude', 
 'NAICS 4 Sector Name (English)', 'NAICS 4 Code', 
'NAICS 6 Sector Name (English)', 'NAICS 6 Code']].drop_duplicates()

# %% [markdown]
# #### Analysis per company and facility

# %%
# Define the category mapping included in the columns of the Excel file 
category_mapping = {
    'Air Emissions': ['Stack Emissions', 'Storage / Handling', 'Fugitive Emissions', 'Spills', 'Other', 'Total'],
    'Water Releases': ['Direct Discharge', 'Spills', 'Leaks', 'Total', 'Receiving Waterbody (English)', 'Receiving Waterbody (French)'],
    'Land Releases': ['Spills', 'Leaks', 'Other', 'Total'],
    'Total Releases': ['Total Releases (Excluding Road Dust)', 'Road Dust Emissions', 'Total Releases Including Road Dust'],
    'On-Site Disposal': ['Land Fill', 'Land Treatment', 'Underground Injection', 'Tailings', 'Waste Rock', 'Total On-Site'],
    'Off-Site Disposal': ['Land Fill', 'Land Treatment', 'Underground Injection', 'Storage', 'Tailings', 'Waste Rock', 'Total Off-Site'],
    'Transfers for Treatment': ['Physical Treatment', 'Chemical Treatment', 'Biological Treatment', 'Incineration', 'Transfer to a Municipal Sewage Treatment Plant', 'Total'],
    'Total On/Off Treatment': ['Total'],
    'Transfers for Recycling': [
        'Energy Recovery', 'Solvent Recovery', 'Organic Compound Recovery', 'Metal Recovery',
        'Inorganic Compound Recovery', 'Acid or Base Recovery', 'Catalyst Recovery',
        'Pollution Abatement Residue Recovery', 'Used Oil Recovery', 'Other', 'Total'
    ],
    'Grand Total': ['Total Releases, Disposals and Transfers for Recycling']
}

# %%
def summarize_emissions_by_facility(df, category_mapping):
    """
    Summarize emissions for all big categories as separate columns with company, facility, and city details.
    """
    results = df[['NPRI ID', 'Company Name', 'Facility Name', 'City', 'CSD', 'NAICS 4 Sector Name (English)', 'NAICS 4 Code',  'NAICS 6 Sector Name (English)', "NAICS 6 Code"]].copy()
    for category, columns in category_mapping.items():
        valid_columns = [col for col in columns if col in df.columns]
        if valid_columns:
            # Sum emissions for the current category
            df[category] = df[valid_columns].apply(pd.to_numeric, errors='coerce').fillna(0).sum(axis=1)
            results[category] = df[category]
    # Group by facility details and sum the emissions for all categories
    results = results.groupby(['NPRI ID', 'Company Name', 'Facility Name', 'City', 'CSD', 'NAICS 4 Sector Name (English)', 'NAICS 4 Code',  'NAICS 6 Sector Name (English)', "NAICS 6 Code"], as_index=False).sum()
    return results

# %%
facility_df = summarize_emissions_by_facility(npri_df, category_mapping)

# %%
facility_metal_mining_df = facility_df[facility_df['NAICS 4 Sector Name (English)'] == 'Metal ore mining']
facility_metal_manufacturing_df = facility_df[facility_df["NAICS 4 Code"].astype(str).str[:3] == "331"]

# %%
facility_metal_mining_df
# Out:
#       NPRI ID                    Company Name             Facility Name  \
# 9          99  Les Mines Agnico Eagle Limitée          Division Laronde
# 71        394               BARRICK GOLD INC.         Nickel Plate Mine
# 196      1147              Cameco Corporation     Rabbit Lake Operation
# 197      1148              Cameco Corporation        Key Lake Operation
# 198      1149              Cameco Corporation  McArthur River Operation
# ...       ...                             ...                       ...
# 5086    33049               Prodigy Gold Inc.               Magino Mine
# 5261    33819       Red Lake Madsen Mine Ltd.      Red Lake Madsen Mine
# 5289    33878         B2Gold Back River Corp.            Goose Property
# 5397    34668             Iamgold Corporation                   Fayolle
# 5481    34791             Teck Metals Limited             Sullivan Mine
#
#                City                              CSD  \
# 9     Rouyn-Noranda                         Preissac
# 71        Penticton           Okanagan-Similkameen G
# 196       Saskatoon     Division No. 18, Unorganized
# 197       Saskatoon     Division No. 18, Unorganized
# 198       Saskatoon     Division No. 18, Unorganized
# ...             ...                              ...
# 5086  Dubreuilville  Algoma, Unorganized, North Part
# 5261         Madsen                         Red Lake
# 5289     Goose Lake           Kitikmeot, Unorganized
# 5397  Rouyn-Noranda                    Rouyn-Noranda
# 5481      Kimberley                        Kimberley
#
#      NAICS 4 Sector Name (English)  NAICS 4 Code  \
# 9                 Metal ore mining          2122
# 71                Metal ore mining          2122
# 196               Metal ore mining          2122
# 197               Metal ore mining          2122
# 198               Metal ore mining          2122
# ...                            ...           ...
# 5086              Metal ore mining          2122
# 5261              Metal ore mining          2122
# 5289              Metal ore mining          2122
# 5397              Metal ore mining          2122
# 5481              Metal ore mining          2122
#
#      NAICS 6 Sector Name (English)  NAICS 6 Code  Air Emissions  \
# 9       Gold and silver ore mining        212220     344.571500
# 71      Gold and silver ore mining        212220       0.000000
# 196             Uranium ore mining        212291     494.926000
# 197             Uranium ore mining        212291     733.476120
# 198             Uranium ore mining        212291     110.566600
# ...                            ...           ...            ...
# 5086    Gold and silver ore mining        212220    1023.246602
# 5261    Gold and silver ore mining        212220       9.165642
# 5289    Gold and silver ore mining        212220    1454.769000
# 5397    Gold and silver ore mining        212220       0.000000
# 5481          Lead-zinc ore mining        212231       0.317600
#
#       Water Releases  Land Releases  Total Releases  On-Site Disposal  \
# 9         863.663150     273.895750     4546.080300     892955.780000
# 71          0.000000       0.000000       67.138000          0.000000
# 196       250.348000     247.463000      946.462000       2646.740000
# 197       562.818920     421.858060     1072.511840     404494.502000
# 198        69.519300      56.585300      238.776600          0.000000
# ...              ...            ...             ...               ...
# 5086      516.523316     511.623301     2694.248798     476617.840536
# 5261       46.559535       4.582821       95.354362      20229.423200
# 5289      727.384500     727.384500     1737.840600       2424.057400
# 5397        0.000000       0.000000       97.542000          0.000000
# 5481     1001.618800       0.162800     2061.549600        125.200000
#
#       Off-Site Disposal  Transfers for Treatment  Total On/Off Treatment  \
# 9         446477.890000               172.285750              172.285750
# 71             0.000000                 0.000000                0.000000
# 196         1323.370000               247.463000              247.463000
# 197       202247.251000               420.816060              420.816060
# 198            0.000000                56.585300               56.585300
# ...                 ...                      ...                     ...
# 5086      238308.920268               511.623301              511.623301
# 5261       10114.711600                 4.582821                4.582821
# 5289        1212.029900               727.384500              727.384500
# 5397           0.000000                 0.000000                0.000000
# 5481          62.600000                 0.158800                0.158800
#
#       Transfers for Recycling    Grand Total
# 9                  273.895750  448750.930150
# 71                   0.000000      33.569000
# 196               2137.409000    3686.547000
# 197               2091.134060  204560.938920
# 198               2054.585300    2119.992300
# ...                       ...            ...
# 5086               511.623301  239656.044667
# 5261                 4.582821   10162.388781
# 5289               727.384500    2080.949600
# 5397                 0.000000      48.771000
# 5481                 0.162800    1093.374800
#
# [101 rows x 19 columns]

# %% [markdown]
# #### Template for data collection

# %%
# We add air, water and land emissions to the template
emissions_columns = ['Facility Name', 'Air Emissions', 'Water Releases', 'Land Releases']

recap_metal_mining_df = pd.merge(
    recap_metal_mining_df, facility_metal_mining_df[emissions_columns], on='Facility Name', how='left'
)
recap_metal_manufacturing_df = pd.merge(
    recap_metal_manufacturing_df, facility_metal_manufacturing_df[emissions_columns], on='Facility Name', how='left'
)

# %%
recap_metal_mining_df
# Out:
#      NPRI ID                            Company Name  \
# 0      11623                   1911 Gold Corporation
# 1       1568                      Agnico Eagle Mines
# 2      25155              Agnico Eagle Mines Limited
# 3      25188       Agnico Eagle Mines Limited (MAIN)
# 4      24216                 Agnico Eagle Mines Ltd.
# ..       ...                                     ...
# 99      6093  Vale Newfoundland and Labrador Limited
# 100    32238                     Victoria Gold Corp.
# 101    10010                 Wesdome Gold Mines Ltd.
# 102    11123                 Wesdome Gold Mines Ltd.
# 103     3197          Williams Operating Corporation
#
#                        Facility Name                    City  \
# 0               True North Gold Mine                 Bissett
# 1                       Macassa Mine           Kirkland Lake
# 2                   Hope Bay Project           Cambridge Bay
# 3             Mine Canadian Malartic                Malartic
# 4                Division Meadowbank              Baker Lake
# ..                               ...                     ...
# 99            Voisey's Bay Mine Site  Happy Valley-Goose Bay
# 100                  Eagle Gold Mine               Vancouver
# 101  Eagle River Mine & Mill Complex                    Wawa
# 102            Eagle River Mine Site                    Wawa
# 103                    Williams Mine                Marathon
#
#                               CSD Province   Latitude   Longitude  \
# 0    Division No. 19, Unorganized       MB  51.021800  -95.679500
# 1                   Kirkland Lake       ON  48.130320  -80.087340
# 2          Kitikmeot, Unorganized       NU  68.039900 -106.574464
# 3                        Malartic       QC  48.124507  -78.129272
# 4           Keewatin, Unorganized       NU  65.014900  -96.052400
# ..                            ...      ...        ...         ...
# 99       Division No. 10, Subd. E       NL  56.337780  -62.094400
# 100            Yukon, Unorganized       YT  64.025450 -135.834300
# 101      Thunder Bay, Unorganized       ON  47.985620  -85.461160
# 102      Thunder Bay, Unorganized       ON  47.986300  -85.461400
# 103      Thunder Bay, Unorganized       ON  48.694200  -85.918800
#
#     NAICS 4 Sector Name (English)  NAICS 4 Code NAICS 6 Sector Name (English)  \
# 0                Metal ore mining          2122    Gold and silver ore mining
# 1                Metal ore mining          2122    Gold and silver ore mining
# 2                Metal ore mining          2122    Gold and silver ore mining
# 3                Metal ore mining          2122    Gold and silver ore mining
# 4                Metal ore mining          2122    Gold and silver ore mining
# ..                            ...           ...                           ...
# 99               Metal ore mining          2122      Nickel-copper ore mining
# 100              Metal ore mining          2122    Gold and silver ore mining
# 101              Metal ore mining          2122    Gold and silver ore mining
# 102              Metal ore mining          2122    Gold and silver ore mining
# 103              Metal ore mining          2122    Gold and silver ore mining
#
#      NAICS 6 Code  Air Emissions  Water Releases  Land Releases
# 0          212220       2.176000        1.088000       1.088000
# 1          212220     674.604440      529.169340     337.302220
# 2          212220    1239.798076      619.899038     796.539038
# 3          212220    3628.942200     1940.931800    1984.111100
# 4          212220    8117.675826     4075.681021    4063.458641
# ..            ...            ...             ...            ...
# 99         212232    8025.111442     4040.531181    4014.318721
# 100        212220    1498.472400      749.236200    1157.616000
# 101        212220       6.397006        3.905922       3.198503
# 102        212220     503.497284      251.748642     251.748642
# 103        212220    1895.302436     1232.023515     947.651218
#
# [104 rows x 15 columns]

# %% [markdown]
# ### 2.1.2 - GHG from large facilities

# %%
ghg_facility_df = pd.read_csv(
    r'data/Emissions_accounts/Raw_data/GHG_large_facilities/Greenhouse gas emissions from large facilities.csv',
    encoding='ISO-8859-1')

# %%
ghg_facility_df
# Out:
#       Facility ID                                      Facility name  \
# 0           10001                                      Division Alma
# 1           10002                Aciérie - ArcelorMittal Contrecoeur
# 2           10003                        Foothills Pipeline, Alberta
# 3           10004                                     Kingston CoGen
# 4           10005                  AGC Flat glass North America ltée
# ...           ...                                                ...
# 2624        12717  Lieu d'enfouissement technique de la Ville de ...
# 2625        12718  Lieu d'enfouissement technique de la ville de ...
# 2626        12719                              Pure Sunfarms Delta 3
# 2627        12720                     KARMAX HEAVY STAMPING - MILTON
# 2628        12721  Lieu d'enfouissement technique de Rivière-du-Loup
#
#                                      Company name                      City  \
# 0                      Produits forestiers Résolu                      Alma
# 1     ArcelorMittal Produits Longs Canada s.e.n.c               Contrecoeur
# 2                       Foothills Pipe Lines Ltd.                   Airdrie
# 3                              Validus Power Corp                      Bath
# 4               AGC Flat glass North America ltée  St Augustin De Desmaures
# ...                                           ...                       ...
# 2624                              Ville de Matane                    Matane
# 2625                           ville de Sept-Iles                 Sept Iles
# 2626                                Pure Sunfarms                     Delta
# 2627                     Magna International Inc.                    Milton
# 2628                     Ville de Rivière-du-Loup                   Cacouna
#
#                                Address Postal code          Province  \
# 0                 1100 Melançon Street     G8B 5W2            Quebec
# 1            0 3900 Route des Aciéries     J0L 1C0            Quebec
# 2                                  NaN     T4A 2G7           Alberta
# 3           5146 Taylor-Kidd Boulevard     K0H 1G0           Ontario
# 4                250 rue de Copenhague     G3A 2H3            Quebec
# ...                                ...         ...               ...
# 2624            330 Yves-Bérubé Street     G4W 3M6            Quebec
# 2625  750 du lac Daigle Road Northeast         NaN            Quebec
# 2626                  4431 80th Street     V4K 3N3  British Columbia
# 2627                  333 Market Drive     L9T 4Z7           Ontario
# 2628          1707 du Patrimoine Route     G0L 1G0            Quebec
#
#       Latitude  Longitude  Total emissions  \
# 0     48.56500  -71.65556            39.08
# 1     45.82055  -73.26362              NaN
# 2      0.00000    0.00000           352.66
# 3     44.20950  -76.72460             1.01
# 4      0.00000    0.00000              NaN
# ...        ...        ...              ...
# 2624  48.81885  -67.57371            21.39
# 2625  50.26970  -66.29690            50.36
# 2626  49.08432 -122.99768            10.08
# 2627  43.52070  -79.91130            10.85
# 2628  47.97480  -69.43849            27.02
#
#                                                   Units  Report year  \
# 0     kilotonnes of carbon dioxide equivalents (kt C...         2022
# 1     kilotonnes of carbon dioxide equivalents (kt C...         2022
# 2     kilotonnes of carbon dioxide equivalents (kt C...         2022
# 3     kilotonnes of carbon dioxide equivalents (kt C...         2022
# 4     kilotonnes of carbon dioxide equivalents (kt C...         2022
# ...                                                 ...          ...
# 2624  kilotonnes of carbon dioxide equivalents (kt C...         2022
# 2625  kilotonnes of carbon dioxide equivalents (kt C...         2022
# 2626  kilotonnes of carbon dioxide equivalents (kt C...         2022
# 2627  kilotonnes of carbon dioxide equivalents (kt C...         2022
# 2628  kilotonnes of carbon dioxide equivalents (kt C...         2022
#
#                                 Industry classification  \
# 0                                 Mechanical Pulp Mills
# 1     Iron and Steel Mills and Ferro-Alloy Manufactu...
# 2                Pipeline Transportation of Natural Gas
# 3                 Fossil-Fuel Electric Power Generation
# 4                                   Glass Manufacturing
# ...                                                 ...
# 2624                       Waste Treatment and Disposal
# 2625                       Waste Treatment and Disposal
# 2626                         Cannabis grown under cover
# 2627                       Motor Vehicle Metal Stamping
# 2628                       Waste Treatment and Disposal
#
#                            Industry classification link  \
# 0     https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 1     https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 2     https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 3     https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 4     https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# ...                                                 ...
# 2624  https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 2625  https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 2626  https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 2627  https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 2628  https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
#
#                                    Facility information  \
# 0     https://climate-change.canada.ca/facility-emis...
# 1     https://climate-change.canada.ca/facility-emis...
# 2     https://climate-change.canada.ca/facility-emis...
# 3     https://climate-change.canada.ca/facility-emis...
# 4     https://climate-change.canada.ca/facility-emis...
# ...                                                 ...
# 2624  https://climate-change.canada.ca/facility-emis...
# 2625  https://climate-change.canada.ca/facility-emis...
# 2626  https://climate-change.canada.ca/facility-emis...
# 2627  https://climate-change.canada.ca/facility-emis...
# 2628  https://climate-change.canada.ca/facility-emis...
#
#                                        Facility details
# 0     http://indicators-map.canada.ca/App/Detail?id=...
# 1     http://indicators-map.canada.ca/App/Detail?id=...
# 2     http://indicators-map.canada.ca/App/Detail?id=...
# 3     http://indicators-map.canada.ca/App/Detail?id=...
# 4     http://indicators-map.canada.ca/App/Detail?id=...
# ...                                                 ...
# 2624  http://indicators-map.canada.ca/App/Detail?id=...
# 2625  http://indicators-map.canada.ca/App/Detail?id=...
# 2626  http://indicators-map.canada.ca/App/Detail?id=...
# 2627  http://indicators-map.canada.ca/App/Detail?id=...
# 2628  http://indicators-map.canada.ca/App/Detail?id=...
#
# [2629 rows x 16 columns]

# %%
# We need to sort it by NAICS list, since they are not properly listed by "hierarchy", e.g. no parent nor code

# %%
# Define classification lists
metal_ore_mining_naics = [
    "Metal ore mining",
    "Iron ore mining",
    "Gold and silver ore mining",
    "Copper, nickel, lead and zinc ore mining",
    "Lead-zinc ore mining",
    "Nickel-copper ore mining",
    "Copper-zinc ore mining",
    "Other metal ore mining",
    "Uranium ore mining",
    "All other metal ore mining",
    "Non-metallic mineral mining and quarrying",
    "Stone mining and quarrying",
    "Granite mining and quarrying",
    "Limestone mining and quarrying",
    "Marble mining and quarrying",
    "Sandstone mining and quarrying",
    "Sand, gravel, clay, and ceramic and refractory minerals mining and quarrying",
    "Sand and gravel mining and quarrying",
    "Shale, clay and refractory mineral mining and quarrying",
    "Other non-metallic mineral mining and quarrying",
    "Diamond mining",
    "Salt mining",
    "Asbestos mining",
    "Gypsum mining",
    "Potash mining",
    "Peat extraction",
    "All other non-metallic mineral mining and quarrying",
    "Support activities for mining, and oil and gas extraction",
    "Oil and gas contract drilling",
    "Contract drilling (except oil and gas)",
    "Services to oil and gas extraction",
    "Other support activities for mining"
]

metal_manufacturing_naics = [
    "Primary metal manufacturing",
    "Iron and steel mills and ferro-alloy manufacturing",
    "Steel product manufacturing from purchased steel",
    "Iron and steel pipes and tubes manufacturing from purchased steel",
    "Rolling and drawing of purchased steel",
    "Cold-rolled steel shape manufacturing",
    "Steel wire drawing",
    "Alumina and aluminum production and processing",
    "Primary production of alumina and aluminum",
    "Aluminum rolling, drawing, extruding and alloying",
    "Non-ferrous metal (except aluminum) production and processing",
    "Non-ferrous metal (except aluminum) smelting and refining",
    "Copper rolling, drawing, extruding and alloying",
    "Non-ferrous metal (except copper and aluminum) rolling, drawing, extruding and alloying",
    "Foundries",
    "Ferrous metal foundries",
    "Iron foundries",
    "Steel foundries",
    "Non-ferrous metal foundries",
    "Non-ferrous metal die-casting foundries",
    "Non-ferrous metal foundries (except die-casting)"
]

# %%
def filter_ghg_facility_naics(df, classifications):
    # Normalize the classifications to lowercase for case-insensitive comparison
    classifications_lower = [cls.lower() for cls in classifications]
    
    df_copy = df.copy()
    df_copy['NAICS_Lower'] = df_copy['Industry classification'].str.lower()
    filtered_df = df_copy[df_copy['NAICS_Lower'].isin(classifications_lower)]
    filtered_df = filtered_df.drop(columns=['NAICS_Lower'])
    filtered_df = filtered_df.reset_index(drop=True)
    
    return filtered_df

# %%
ghg_facility_df_metal_mining = filter_ghg_facility_naics(ghg_facility_df, metal_ore_mining_naics)
ghg_facility_df_metal_manufacturing = filter_ghg_facility_naics(ghg_facility_df, metal_manufacturing_naics)

# %%
ghg_facility_df_metal_manufacturing
# Out:
#     Facility ID                          Facility name  \
# 0         10002    Aciérie - ArcelorMittal Contrecoeur
# 1         10010                   Rio Tinto Alcan Inc.
# 2         10011                       Algoma Steel Inc
# 3         10012               Aluminerie Alouette inc.
# 4         10013              Aluminerie de Baie-Comeau
# ..          ...                                    ...
# 68        12301              GRIFFIN CANADA - WINNIPEG
# 69        12554                 Molycop Canada Plant 2
# 70        12555                        Moly-Cop Canada
# 71        12579                       Fonderie Laperle
# 72        12581  Extrusion North America - Mississauga
#
#                                    Company name              City  \
# 0   ArcelorMittal Produits Longs Canada s.e.n.c       Contrecoeur
# 1                           Rio Tinto Alcan Inc           Kitimat
# 2                             Algoma Steel Inc.  Sault Ste. Marie
# 3                      Aluminerie Alouette inc.          SeptÎles
# 4             Ne pas prendre - Alcoa Canada Co.       Baie Comeau
# ..                                          ...               ...
# 68                          Griffin Canada Inc.          Winnipeg
# 69                              Moly-Cop Canada          Kamloops
# 70                              Moly-Cop Canada          Kamloops
# 71                           Canada Pipe Co ltd        Saint Ours
# 72                 Hydro Extrusion Canada, Inc.       Mississauga
#
#                              Address Postal code          Province  Latitude  \
# 0          0 3900 Route des Aciéries     J0L 1C0            Quebec  45.82055
# 1                 1 Smeltersite Road     V8C 2H2  British Columbia  54.00286
# 2              105 West Street North     P6A 7B4           Ontario  46.52170
# 3   400 Chemin de de la Pointe-Noire     G4R 5M9            Quebec  50.15830
# 4               0 100 Maritime Route     G4Z 2L6            Quebec  49.25830
# ..                               ...         ...               ...       ...
# 68                   2500 Day Street     R2C 3A4          Manitoba  49.91300
# 69              300 Andover Crescent     V2C 6X2  British Columbia  50.65598
# 70              250 Andover Crescent     V2C 6X2  British Columbia  50.65726
# 71            106 montée de la Basse     J0G 1P0            Quebec  45.89470
# 72                 5675 Kennedy Road     L4Z 2H9           Ontario  43.63060
#
#     Longitude  Total emissions  \
# 0   -73.26362              NaN
# 1  -128.69531           420.39
# 2   -84.36370          3936.24
# 3   -66.44160          1140.90
# 4   -68.14610           534.69
# ..        ...              ...
# 68  -97.00250              NaN
# 69 -120.09703              NaN
# 70 -120.09649            25.12
# 71  -73.13870             0.51
# 72  -79.65750             4.89
#
#                                                 Units  Report year  \
# 0   kilotonnes of carbon dioxide equivalents (kt C...         2022
# 1   kilotonnes of carbon dioxide equivalents (kt C...         2022
# 2   kilotonnes of carbon dioxide equivalents (kt C...         2022
# 3   kilotonnes of carbon dioxide equivalents (kt C...         2022
# 4   kilotonnes of carbon dioxide equivalents (kt C...         2022
# ..                                                ...          ...
# 68  kilotonnes of carbon dioxide equivalents (kt C...         2022
# 69  kilotonnes of carbon dioxide equivalents (kt C...         2022
# 70  kilotonnes of carbon dioxide equivalents (kt C...         2022
# 71  kilotonnes of carbon dioxide equivalents (kt C...         2022
# 72  kilotonnes of carbon dioxide equivalents (kt C...         2022
#
#                               Industry classification  \
# 0   Iron and Steel Mills and Ferro-Alloy Manufactu...
# 1          Primary Production of Alumina and Aluminum
# 2   Iron and Steel Mills and Ferro-Alloy Manufactu...
# 3          Primary Production of Alumina and Aluminum
# 4          Primary Production of Alumina and Aluminum
# ..                                                ...
# 68                                    Steel Foundries
# 69                                     Iron Foundries
# 70                                     Iron Foundries
# 71                                     Iron Foundries
# 72  Aluminum Rolling, Drawing, Extruding and Alloying
#
#                          Industry classification link  \
# 0   https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 1   https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 2   https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 3   https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 4   https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# ..                                                ...
# 68  https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 69  https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 70  https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 71  https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
# 72  https://www23.statcan.gc.ca/imdb/p3VD.pl?Funct...
#
#                                  Facility information  \
# 0   https://climate-change.canada.ca/facility-emis...
# 1   https://climate-change.canada.ca/facility-emis...
# 2   https://climate-change.canada.ca/facility-emis...
# 3   https://climate-change.canada.ca/facility-emis...
# 4   https://climate-change.canada.ca/facility-emis...
# ..                                                ...
# 68  https://climate-change.canada.ca/facility-emis...
# 69  https://climate-change.canada.ca/facility-emis...
# 70  https://climate-change.canada.ca/facility-emis...
# 71  https://climate-change.canada.ca/facility-emis...
# 72  https://climate-change.canada.ca/facility-emis...
#
#                                      Facility details
# 0   http://indicators-map.canada.ca/App/Detail?id=...
# 1   http://indicators-map.canada.ca/App/Detail?id=...
# 2   http://indicators-map.canada.ca/App/Detail?id=...
# 3   http://indicators-map.canada.ca/App/Detail?id=...
# 4   http://indicators-map.canada.ca/App/Detail?id=...
# ..                                                ...
# 68  http://indicators-map.canada.ca/App/Detail?id=...
# 69  http://indicators-map.canada.ca/App/Detail?id=...
# 70  http://indicators-map.canada.ca/App/Detail?id=...
# 71  http://indicators-map.canada.ca/App/Detail?id=...
# 72  http://indicators-map.canada.ca/App/Detail?id=...
#
# [73 rows x 16 columns]

# %% [markdown]
# ### 2.1.3 NRCan's 900A

# %%
nrcan_mining_df = pd.read_excel(r'data/NRCan/Principal Mineral Areas, Producing Mines, and Oil and Gas Fields (900A)/producing_mines.xlsx')
nrcan_manufacturing_df = pd.read_excel(r'data/NRCan/Principal Mineral Areas, Producing Mines, and Oil and Gas Fields (900A)/metal_work.xlsx')

# %%
nrcan_mining_df
# Out:
#             OPERATIO_E         OPERATIO_F                     OWNER_E  \
# 0       Sleeping Giant      Géant Dormant          Abcourt Mines Inc.
# 1               Amaruq             Amaruq  Agnico Eagle Mines Limited
# 2    Canadian Malartic  Canadian Malartic  Agnico Eagle Mines Limited
# 3          Detour Lake        Detour Lake  Agnico Eagle Mines Limited
# 4               Goldex             Goldex  Agnico Eagle Mines Limited
# ..                 ...                ...                         ...
# 194              Mishi              Mishi     Wesdome Gold Mines Ltd.
# 195        Coal Valley        Coal Valley   Westmoreland Coal Company
# 196            Estevan            Estevan   Westmoreland Coal Company
# 197            Genesee            Genesee   Westmoreland Coal Company
# 198       Poplar River       Poplar River   Westmoreland Coal Company
#
#                         OWNER_F FAC_TYPE_E     FAC_TYPE_F  \
# 0            Mines Abcourt Inc.       (C.)         (Con.)
# 1    Mines Agnico Eagle Limitée   (P., U.)  (C.O., Sout.)
# 2    Mines Agnico Eagle Limitée   (P., C.)   (C.O., Con.)
# 3    Mines Agnico Eagle Limitée   (P., C.)   (C.O., Con.)
# 4    Mines Agnico Eagle Limitée   (U., C.)  (Sout., Con.)
# ..                          ...        ...            ...
# 194     Mines d’Or Wesdome Ltée       (P.)         (C.O.)
# 195   Westmoreland Coal Company       (P.)         (C.O.)
# 196   Westmoreland Coal Company       (P.)         (C.O.)
# 197   Westmoreland Coal Company       (P.)         (C.O.)
# 198   Westmoreland Coal Company       (P.)         (C.O.)
#
#                     FAC_DESC_E                  FAC_DESC_F      COMMODIT_E  \
# 0                 Concentrator               Concentrateur          Au, Ag
# 1        Open-pit, underground    Ciel ouvert, souterraine              Au
# 2       Open-pit, concentrator  Ciel ouvert, concentrateur          Au, Ag
# 3       Open-pit, concentrator  Ciel ouvert, concentrateur              Au
# 4    Underground, concentrator  Souterraine, concentrateur          Au, Ag
# ..                         ...                         ...             ...
# 194                   Open-pit                 Ciel ouvert              Au
# 195                   Open-pit                 Ciel ouvert  Coal (thermal)
# 196                   Open-pit                 Ciel ouvert  Coal (thermal)
# 197                   Open-pit                 Ciel ouvert  Coal (thermal)
# 198                   Open-pit                 Ciel ouvert  Coal (thermal)
#
#               COMMODIT_F      COM_DESC_E           COM_DESC_F  \
# 0                 Au, Ag    Gold, silver           Or, argent
# 1                     Au            Gold                   Or
# 2                 Au, Ag    Gold, silver           Or, argent
# 3                     Au            Gold                   Or
# 4                 Au, Ag    Gold, silver           Or, argent
# ..                   ...             ...                  ...
# 194                   Au            Gold                   Or
# 195  Charbon (thermique)  Coal (thermal)  Charbon (thermique)
# 196  Charbon (thermique)  Coal (thermal)  Charbon (thermique)
# 197  Charbon (thermique)  Coal (thermal)  Charbon (thermique)
# 198  Charbon (thermique)  Coal (thermal)  Charbon (thermique)
#
#           COM_GROU_E       COM_GROU_F                 CITY_E  \
# 0    Precious metals  Métaux précieux          north of Amos
# 1    Precious metals  Métaux précieux             Baker Lake
# 2    Precious metals  Métaux précieux               Malartic
# 3    Precious metals  Métaux précieux  Northeast of Cochrane
# 4    Precious metals  Métaux précieux               Val-d’Or
# ..               ...              ...                    ...
# 194  Precious metals  Métaux précieux                   Wawa
# 195             Coal          Charbon                  Edson
# 196             Coal          Charbon               Bienfait
# 197             Coal          Charbon                Genesee
# 198             Coal          Charbon               Coronach
#
#                       CITY_F    PROVINCE_E    PROVINCE_F   LATITUDE  \
# 0             au nord d’Amos        Quebec        Québec  49.132590
# 1                 Baker Lake       Nunavut       Nunavut  65.415000
# 2                   Malartic        Quebec        Québec  48.122223
# 3    au nord-est de Cochrane       Ontario       Ontario  50.018143
# 4                   Val-d’Or        Quebec        Québec  48.092600
# ..                       ...           ...           ...        ...
# 194                     Wawa       Ontario       Ontario  48.110280
# 195                    Edson       Alberta       Alberta  53.072796
# 196                 Bienfait  Saskatchewan  Saskatchewan  49.087329
# 197                  Genesee       Alberta       Alberta  53.323876
# 198                 Coronach  Saskatchewan  Saskatchewan  49.217566
#
#       LONGITUDE
# 0    -77.974340
# 1    -96.697000
# 2    -78.130824
# 3    -79.717631
# 4    -77.873300
# ..          ...
# 194  -85.452500
# 195 -116.786616
# 196 -102.864956
# 197 -114.267236
# 198 -105.472585
#
# [199 rows x 20 columns]

# %%
nrcan_manufacturing_df
# Out:
#                    OPERATIO_E                 OPERATIO_F  \
# 0                 Baie-Comeau                Baie-Comeau
# 1                Deschambault               Deschambault
# 2                   Bécancour                  Bécancour
# 3                Algoma Steel               Algoma Steel
# 4                   AltaSteel                  AltaSteel
# ..                        ...                        ...
# 68  Sault Ste. Marie Division  Division Sault Ste. Marie
# 69               Welland Mill         Aciérie de Welland
# 70       Copper Cliff Complex      Complexe Copper Cliff
# 71              Port Colborne              Port Colborne
# 72               Long Harbour               Long Harbour
#
#                                           OWNER_E  \
# 0                               Alcoa Corporation
# 1                               Alcoa Corporation
# 2   Alcoa Corporation and Rio Tinto Aluminum Inc.
# 3                               Algoma Steel Inc.
# 4                                  AltaSteel Inc.
# ..                                            ...
# 68                              Triple M Metal LP
# 69                              Valbruna ASW Inc.
# 70                            Vale Canada Limited
# 71                            Vale Canada Limited
# 72         Vale Newfoundland and Labrador Limited
#
#                                          OWNER_F                FAC_TYPE_E  \
# 0                              Alcoa Corporation                   Smelter
# 1                              Alcoa Corporation                   Smelter
# 2   Alcoa Corporation et Rio Tinto Aluminum Inc.                   Smelter
# 3                              Algoma Steel Inc.      Basic oxygen furnace
# 4                                 AltaSteel Inc.      Electric arc furnace
# ..                                           ...                       ...
# 68                             Triple M Metal LP                       NaN
# 69                             Valbruna ASW Inc.      Electric arc furnace
# 70                           Vale Canada Limitée  Smelter, refinery, plant
# 71                           Vale Canada Limitée                  Refinery
# 72        Vale Newfoundland and Labrador Limited                  Refinery
#
#                            FAC_TYPE_F   COM_GROU_E      COM_GROU_F  \
# 0                     Usine de fusion     Aluminum        Aluminum
# 1                     Usine de fusion     Aluminum        Aluminum
# 2                     Usine de fusion     Aluminum        Aluminum
# 3     Convertisseur basique à oxygène     Iron ore  Minerai de fer
# 4               Four électrique à arc     Iron ore  Minerai de fer
# ..                                ...          ...             ...
# 68                                NaN          NaN             NaN
# 69              Four électrique à arc     Iron ore  Minerai de fer
# 70  Usine de fusion, affinerie, usine  Base metals  Métaux communs
# 71                          Affinerie  Base metals  Métaux communs
# 72                          Affinerie  Base metals  Métaux communs
#
#                                            COM_DESC_E  \
# 0                          Aluminum (pure or alloyed)
# 1                                     Aluminum (pure)
# 2                          Aluminum (pure or alloyed)
# 3                                               Steel
# 4                                               Steel
# ..                                                ...
# 68                                                NaN
# 69                                              Steel
# 70  Nickel (oxide sinter, pellets, powder, sulfide...
# 71  Electrolytic cobalt, platinum group metals (in...
# 72                             Nickel, copper, cobalt
#
#                                            COM_DESC_F  \
# 0                            Aluminium (pur ou allié)
# 1                                     Aluminium (pur)
# 2                            Aluminium (pur ou allié)
# 3                                               Acier
# 4                                               Acier
# ..                                                ...
# 68                                                NaN
# 69                                              Acier
# 70  Nickel (sinters d’oxydes, boulettes, poudre, s...
# 71  Cobalt (production électrolytique), métaux du ...
# 72                             Nickel, cuivre, cobalt
#
#                    PROVINCE_E               PROVINCE_F   LATITUDE   LONGITUDE
# 0                      Quebec                   Québec  49.256200  -68.149100
# 1                      Quebec                   Québec  46.693900  -71.946700
# 2                      Quebec                   Québec  46.381000  -72.385200
# 3                     Ontario                  Ontario  46.520550  -84.366640
# 4                     Alberta                  Alberta  53.492783 -113.387962
# ..                        ...                      ...        ...         ...
# 68                    Ontario                  Ontario  46.524326  -84.395602
# 69                    Ontario                  Ontario  42.998265  -79.235065
# 70                    Ontario                  Ontario  46.480100  -81.056900
# 71                    Ontario                  Ontario  42.883000  -79.240000
# 72  Newfoundland and Labrador  Terre-Neuve et Labrador  47.410938  -53.811792
#
# [73 rows x 14 columns]

# %% [markdown]
# ### 2.1.4 MinCan database from Dallaire-Fortin (2024)

# %%
min_can = pd.read_excel(r'data/Mining_production_data/MinCan _Past and Present Productive Mines of Canada, 1950-2022_March2024.xlsx', sheet_name='Data')
min_can
# Out:
#                                               company1  \
# 0                              Quebec Copper Corp. Ltd
# 1                                    Noland Mines Ltd.
# 2                      Falconbridge Nickel Mines Ltd.
# 3                             Greenwood Coal Co. Ltd.
# 4                                    Noranda Mines Ltd
# ..                                                 ...
# 942  Imperial Metals Corporation, Mitsubishi Materi...
# 943                                  BHP Diamonds Inc.
# 944                            Magnola Magnesium Inc.
# 945                   Canadian Johns-Manville Co. Ltd.
# 946                    Crow's Nest Pass Coal Co. Ltd.
#
#                                       company2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4             Normetal Mining Corporation Ltd.
# ..                                         ...
# 942                     Teck Resources Limited
# 943                      Dia Met Minerals Ltd.
# 944  Society generale de financement du Quebec
# 945                              Asbestos Inc.
# 946                                        NaN
#
#                                company3                         company4  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                     Falconbridge Ltd.                          Xstrata
# ..                                  ...                              ...
# 942              Huckleberry Mines Ltd.                              NaN
# 943   Charles Fipke and Stewart Blusson  Arctic Canadian Diamond Company
# 944                                 NaN                              NaN
# 945                                 NaN                              NaN
# 946                                 NaN                              NaN
#
#     company5 company6               namemine                        town  \
# 0        NaN      NaN                    NaN                         NaN
# 1        NaN      NaN           Spruce Creek                       Atlin
# 2        NaN      NaN         Wesfrob (Tasu)             Moresby Island
# 3        NaN      NaN                    NaN                         NaN
# 4        NaN      NaN                  Horne                    Noranda
# ..       ...      ...                    ...                         ...
# 942      NaN      NaN            Huckleberry                      Kemano
# 943      NaN      NaN  Panda (Ekati Project)                 Lac de Gras
# 944      NaN      NaN               Ardorbec                   Danville
# 945      NaN      NaN                Jeffrey  Asbestos (Val-des-Sources)
# 946      NaN      NaN                    NaN                         NaN
#
#                   province   latitude  ...  commodity6  commodity7 commodity8  \
# 0                   Quebec  45.263786  ...         NaN         NaN        NaN
# 1         British Columbia  59.382720  ...         NaN         NaN        NaN
# 2         British Columbia  52.758340  ...         NaN         NaN        NaN
# 3              Nova Scotia  45.550219  ...         NaN         NaN        NaN
# 4                   Quebec  48.254270  ...      Pyrite         NaN        NaN
# ..                     ...        ...  ...         ...         ...        ...
# 942       British Columbia  53.681110  ...         NaN         NaN        NaN
# 943  Northwest Territories  64.716667  ...         NaN         NaN        NaN
# 944                 Quebec  45.748462  ...         NaN         NaN        NaN
# 945                 Quebec  45.775100  ...         NaN         NaN        NaN
# 946       British Columbia  49.654481  ...         NaN         NaN        NaN
#
#                                            information source1 source2  \
# 0                                                  NaN       0       1
# 1                                                  NaN       0       1
# 2                                                  NaN       0       1
# 3    The currently entered coordinates are for the ...       0       1
# 4    Alternative names: Horne Mine (1975) The mine ...       0       1
# ..                                                 ...     ...     ...
# 942                                                NaN       1       0
# 943                Brief closure between 2020 and 2021       1       0
# 944                                                NaN       1       0
# 945  FR: En 1992, la mine est l'objet d'une importa...       0       0
# 946  The Crow's Nest Pass Coal Company was establis...       0       0
#
#     source3                                              link1  \
# 0         0                                                NaN
# 1         1        https://www.mindat.org/feature-6088912.html
# 2         1              https://www.mindat.org/loc-26169.html
# 3         1             https://www.mindat.org/loc-290980.html
# 4         1                https://www.mindat.org/loc-609.html
# ..      ...                                                ...
# 942       0                                                NaN
# 943       0                                                NaN
# 944       0                                                NaN
# 945       1  https://miningwatch.ca/sites/default/files/asb...
# 946       1  https://albertaonrecord.ca/crowsnest-resources...
#
#                                                  link2  \
# 0                                                  NaN
# 1               https://www.mindat.org/loc-257276.html
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 942                                                NaN
# 943                                                NaN
# 944                                                NaN
# 945  https://niche-canada.org/2015/11/19/workers-as...
# 946                                                NaN
#
#                                                  link3
# 0                                                  NaN
# 1    https://mrdata.usgs.gov/ardf/show-ardf.php?ard...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 942                                                NaN
# 943                                                NaN
# 944                                                NaN
# 945  https://www.researchgate.net/publication/28664...
# 946                                                NaN
#
# [947 rows x 33 columns]

# %%
def is_mine_active(row):
    current_year = 2022  # As mentioned in the explanation
    
    # Convert year values to integers, ignoring non-numeric values
    def to_int(value):
        try:
            return int(value)
        except (ValueError, TypeError):
            return None
    
    # Convert all year columns to integers
    open1 = to_int(row['open1'])
    close1 = to_int(row['close1'])
    open2 = to_int(row['open2'])
    close2 = to_int(row['close2'])
    open3 = to_int(row['open3'])
    close3 = to_int(row['close3'])
    
    # Check if any of the 'close' columns have the value 'open'
    if row['close1'] == 'open' or row['close2'] == 'open' or row['close3'] == 'open':
        return 'Active'
    
    # Find the latest year among open and close columns
    years = [open1, close1, open2, close2, open3, close3]
    years = [year for year in years if year is not None]
    
    if not years:
        return 'Unknown'
    
    latest_year = max(years)
    
    # If the latest year is a 'close' year, the mine is inactive
    if latest_year in [close1, close2, close3]:
        return 'Inactive'
    
    # If the latest year is an 'open' year and it's the current year or later, consider it active
    if latest_year in [open1, open2, open3] and latest_year >= current_year:
        return 'Active'
    
    # For all other cases, consider it inactive
    return 'Inactive'

# %%
# Apply the function to create a new column 'mine_status'
min_can['mine_status'] = min_can.apply(is_mine_active, axis=1)

# %%
min_can['mine_status'].value_counts()
# Out:
# mine_status
# Inactive    776
# Active      171
# Name: count, dtype: int64

# %%
min_can = min_can[min_can['mine_status'] == 'Active']

# %%
min_can
# Out:
#                                   company1  \
# 7                 Dominion Magnesium Ltd.
# 13                            Noranda Inc.
# 18              Steep Rock Iron Mines Ltd.
# 23   Marietta Resources International Ltd.
# 24          Baskatong Quartz Products Ltd.
# ..                                     ...
# 931              BP Ressources Canada Ltd.
# 932                  Continental Lime Ltd.
# 935                   Red Deer Silica Inc.
# 943                      BHP Diamonds Inc.
# 944                Magnola Magnesium Inc.
#
#                                               company2  \
# 7                           Chromasco Corporation Ltd.
# 13   Brunswick Mining and Smelting Corporation Limi...
# 18                                  OMYA (Canada) Inc.
# 23                                   Lacana Mines Inc.
# 24                                   Sitec Quartz Inc.
# ..                                                 ...
# 931                                             Lhoist
# 932                       Graymont Western Canada Inc.
# 935                                                NaN
# 943                              Dia Met Minerals Ltd.
# 944          Society generale de financement du Quebec
#
#                                company3  \
# 7                      Timminco Limited
# 13                                  NaN
# 18                                  NaN
# 23                    Zemex Corporation
# 24                      SKW Canada Inc.
# ..                                  ...
# 931                                 NaN
# 932                                 NaN
# 935                                 NaN
# 943   Charles Fipke and Stewart Blusson
# 944                                 NaN
#
#                                    company4 company5 company6  \
# 7                                       NaN      NaN      NaN
# 13                                      NaN      NaN      NaN
# 18                                      NaN      NaN      NaN
# 23   Suzorite Mica products of Boucherville      NaN      NaN
# 24                      Hogan Holdings Inc.      NaN      NaN
# ..                                      ...      ...      ...
# 931                                     NaN      NaN      NaN
# 932                                     NaN      NaN      NaN
# 935                                     NaN      NaN      NaN
# 943         Arctic Canadian Diamond Company      NaN      NaN
# 944                                     NaN      NaN      NaN
#
#                   namemine                       town               province  \
# 7                    Haley                     Haley                 Ontario
# 13     Stratmat (Halfmile)                        NaN          New Brunswick
# 18        Calcite Division                      Perth                Ontario
# 23     Parent Mica Deposit                      Suzor                 Quebec
# 24              Charlevoix  Charlevoix (Saint-Urbain)                 Quebec
# ..                     ...                        ...                    ...
# 931                    NaN               Fort Langley       British Columbia
# 932                    NaN                     Exshaw                Alberta
# 935                    NaN                Hudson Bay            Saskatchewan
# 943  Panda (Ekati Project)                Lac de Gras  Northwest Territories
# 944               Ardorbec                  Danville                  Quebec
#
#       latitude  ...  commodity7  commodity8  \
# 7    45.598880  ...         NaN         NaN
# 13   47.305278  ...         NaN         NaN
# 18   45.149689  ...         NaN         NaN
# 23   47.938412  ...         NaN         NaN
# 24   47.749900  ...         NaN         NaN
# ..         ...  ...         ...         ...
# 931  49.189659  ...         NaN         NaN
# 932  51.071389  ...         NaN         NaN
# 935  52.985830  ...         NaN         NaN
# 943  64.716667  ...         NaN         NaN
# 944  45.748462  ...         NaN         NaN
#
#                                            information source1 source2  \
# 7                                                  NaN       0       1
# 13                            indigenous participation       0       1
# 18                                                 NaN       0       1
# 23   Changed name in Lacana Mines Inc. "In late 198...       0       1
# 24                                                 NaN       0       1
# ..                                                 ...     ...     ...
# 931                                                NaN       1       0
# 932                                                NaN       1       0
# 935  small scale /// Lower Cretaceous Mannville Gro...       1       0
# 943                Brief closure between 2020 and 2021       1       0
# 944                                                NaN       1       0
#
#     source3                                              link1  \
# 7         1  http://www.geologyontario.mndm.gov.on.ca/mndmf...
# 13        1  https://www.nrcan.gc.ca/sites/www.nrcan.gc.ca/...
# 18        1  http://www.geologyontario.mndm.gov.on.ca/mndmf...
# 23        1  https://cmscontent.nrs.gov.bc.ca/geoscience/Pu...
# 24        1  https://gq.mines.gouv.qc.ca/documents/examine/...
# ..      ...                                                ...
# 931       0                                                NaN
# 932       0                                                NaN
# 935       0                                                NaN
# 943       0                                                NaN
# 944       0                                                NaN
#
#                                                  link2 link3 mine_status
# 7                https://www.mindat.org/loc-14742.html   NaN      Active
# 13                                                 NaN   NaN      Active
# 18                                                 NaN   NaN      Active
# 23   https://gq.mines.gouv.qc.ca/documents/examine/...   NaN      Active
# 24   https://www.globenewswire.com/news-release/201...   NaN      Active
# ..                                                 ...   ...         ...
# 931                                                NaN   NaN      Active
# 932                                                NaN   NaN      Active
# 935                                                NaN   NaN      Active
# 943                                                NaN   NaN      Active
# 944                                                NaN   NaN      Active
#
# [171 rows x 34 columns]

# %% [markdown]
# ## 2.2 Merge NPRI, GHG and NRCan datasets

# %% [markdown]
# We want to automatically add information from the GHG for large facility and NRCan datasets to the cleaned NPRI data.

# %%
def merge_datasets_by_coordinates(df1, df2, df3, df4, atol=0.01):
    """
    Merge three DataFrames (df1, df2, df3) by matching geographic coordinates (latitude and longitude).
    Adds additional columns for matched facility names, company names, and other relevant columns.

    Parameters:
        df1 (DataFrame): The main DataFrame containing 'Latitude' and 'Longitude'.
        df2 (DataFrame): The secondary DataFrame containing 'Latitude', 'Longitude', 'Facility name',
                         'Company name', 'Total emissions', and 'Facility ID'.
        df3 (DataFrame): The tertiary DataFrame containing 'Latitude', 'Longitude', 'Facility name',
                         'Company name', 'FAC_DESC_E', and 'COM_DESC_E'.
        atol (float): Absolute tolerance for coordinate matching. Default is 0.01 (~1.1 km).

    Returns:
        DataFrame: A copy of df1 with additional columns for matched data from df2 and df3.
    """
    # Standardize column names for consistency
    df1 = df1.rename(columns={"Latitude": "latitude", "Longitude": "longitude"}).copy()
    df2 = df2.rename(columns={"Latitude": "latitude", "Longitude": "longitude", "Facility name": "facility_name", "Company name": "company_name"}).copy()
    df3 = df3.rename(columns={"LATITUDE": "latitude", "LONGITUDE": "longitude", "OPERATIO_E": "facility_name", "OWNER_E": "company_name"}).copy()
    df4 = df4.copy()

    # Initialize additional columns for coordinates and metadata from df2 and df3
    df1['latitude_df2'] = "no coordinates matching found"
    df1['longitude_df2'] = "no coordinates matching found"
    df1['latitude_df3'] = "no coordinates matching found"
    df1['longitude_df3'] = "no coordinates matching found"
    df1['facility_name_df2'] = None
    df1['company_name_df2'] = None
    df1['facility_name_df3'] = None
    df1['company_name_df3'] = None
    df1['FAC_TYPE_E'] = None
    df1['COM_DESC_E'] = None
    df1['Total emissions'] = None
    df1['Facility ID'] = None
    df1['link1'] = None
    df1['link2'] = None

    # Match and add coordinates and metadata from df2
    def match_coordinates_df2(row):
        matching_row = df2[
            (np.isclose(df2['latitude'], row['latitude'], atol=atol)) & 
            (np.isclose(df2['longitude'], row['longitude'], atol=atol))
        ]
        if not matching_row.empty:
            match = matching_row.iloc[0]
            return [
                match['latitude'],
                match['longitude'],
                match['facility_name'],
                match['company_name'],
                match['Total emissions'],
                match['Facility ID']
            ]
        return ["no coordinates matching found", "no coordinates matching found", None, None, None, None]

    df1[['latitude_df2', 'longitude_df2', 'facility_name_df2', 'company_name_df2', 'Total emissions', 'Facility ID']] = df1.apply(
        match_coordinates_df2, axis=1, result_type='expand')

    # Match and add coordinates and metadata from df3
    def match_coordinates_df3(row):
        matching_row = df3[
            (np.isclose(df3['latitude'], row['latitude'], atol=atol)) & 
            (np.isclose(df3['longitude'], row['longitude'], atol=atol))
        ]
        if not matching_row.empty:
            match = matching_row.iloc[0]
            return [
                match['latitude'],
                match['longitude'],
                match['facility_name'],
                match['company_name'],
                match['FAC_TYPE_E'],
                match['COM_DESC_E']
            ]
        return ["no coordinates matching found", "no coordinates matching found", None, None, None, None]

    df1[['latitude_df3', 'longitude_df3', 'facility_name_df3', 'company_name_df3', 'FAC_TYPE_E', 'COM_DESC_E']] = df1.apply(
        match_coordinates_df3, axis=1, result_type='expand')
    
    # Match and add coordinates and metadata from df4
    def match_coordinates_df4(row):
        matching_row = df4[
            (np.isclose(df4['latitude'], row['latitude'], atol=atol)) & 
            (np.isclose(df4['longitude'], row['longitude'], atol=atol))
        ]
        if not matching_row.empty:
            match = matching_row.iloc[0]
            return [
                match['latitude'],
                match['longitude'],
                match['link1'],
                match['link2'],
                match['link3'],
            ]
        return ["no coordinates matching found", "no coordinates matching found", None, None, None]

    df1[['latitude_df4', 'longitude_df4', 'link1', 'link2', 'link3']] = df1.apply(
        match_coordinates_df4, axis=1, result_type='expand')
    
    # Calculate match percentages
    matches_df2 = df1['latitude_df2'].ne("no coordinates matching found").sum()
    matches_df3 = df1['latitude_df3'].ne("no coordinates matching found").sum()
    matches_df4 = df1['latitude_df4'].ne("no coordinates matching found").sum()
    total_rows = len(df1)

    match_percentage_df2 = (matches_df2 / total_rows) * 100
    match_percentage_df3 = (matches_df3 / total_rows) * 100
    match_percentage_df4 = (matches_df4 / total_rows) * 100

    print(f"Match Percentage between df1 and df2: {match_percentage_df2:.2f}%")
    print(f"Match Percentage between df1 and df3: {match_percentage_df3:.2f}%")
    print(f"Match Percentage between df1 and df4: {match_percentage_df4:.2f}%")
    
    df1.rename(
        columns={
    "Company Name": "Company_Name_NPRI", 
    "Facility Name": "Facility_Name_NPRI",
    "latitude": "Latitude_NPRI",
    "longitude": "Longitude_NPRI",
    "latitude_df2": "Latitude_GHG",
    "longitude_df2": "Longitude_GHG",
    "latitude_df3": "Latitude_NRCan",
    "longitude_df3": "Longitude_NRCan",
    "facility_name_df2": "Facility_Name_GHG",
    "company_name_df2": "Company_Name_GHG",
    "facility_name_df3": "Facility_Name_NRCan",
    "company_name_df3": "Company_Name_NRCan",
    "FAC_TYPE_E": "Mining_Processing_Type", 
    "COM_DESC_E": "Commodities",
    "Total emissions": "GHGE (ktCO2eq)",
    "Facility ID": "GHG ID",
    "link1": "Link1_MinCan",
    "link2": "Link2_MinCan",
    "link3": "Link3_MinCan"
        }, inplace=True
    )

    return df1

# %%
mining_df = merge_datasets_by_coordinates(
    recap_metal_mining_df, ghg_facility_df_metal_mining, nrcan_mining_df, min_can,
    atol=0.1)
# Out:
# Match Percentage between df1 and df2: 63.46%
# Match Percentage between df1 and df3: 70.19%
# Match Percentage between df1 and df4: 53.85%

# %%
mining_df
# Out:
#      NPRI ID                       Company_Name_NPRI  \
# 0      11623                   1911 Gold Corporation
# 1       1568                      Agnico Eagle Mines
# 2      25155              Agnico Eagle Mines Limited
# 3      25188       Agnico Eagle Mines Limited (MAIN)
# 4      24216                 Agnico Eagle Mines Ltd.
# ..       ...                                     ...
# 99      6093  Vale Newfoundland and Labrador Limited
# 100    32238                     Victoria Gold Corp.
# 101    10010                 Wesdome Gold Mines Ltd.
# 102    11123                 Wesdome Gold Mines Ltd.
# 103     3197          Williams Operating Corporation
#
#                   Facility_Name_NPRI                    City  \
# 0               True North Gold Mine                 Bissett
# 1                       Macassa Mine           Kirkland Lake
# 2                   Hope Bay Project           Cambridge Bay
# 3             Mine Canadian Malartic                Malartic
# 4                Division Meadowbank              Baker Lake
# ..                               ...                     ...
# 99            Voisey's Bay Mine Site  Happy Valley-Goose Bay
# 100                  Eagle Gold Mine               Vancouver
# 101  Eagle River Mine & Mill Complex                    Wawa
# 102            Eagle River Mine Site                    Wawa
# 103                    Williams Mine                Marathon
#
#                               CSD Province  Latitude_NPRI  Longitude_NPRI  \
# 0    Division No. 19, Unorganized       MB      51.021800      -95.679500
# 1                   Kirkland Lake       ON      48.130320      -80.087340
# 2          Kitikmeot, Unorganized       NU      68.039900     -106.574464
# 3                        Malartic       QC      48.124507      -78.129272
# 4           Keewatin, Unorganized       NU      65.014900      -96.052400
# ..                            ...      ...            ...             ...
# 99       Division No. 10, Subd. E       NL      56.337780      -62.094400
# 100            Yukon, Unorganized       YT      64.025450     -135.834300
# 101      Thunder Bay, Unorganized       ON      47.985620      -85.461160
# 102      Thunder Bay, Unorganized       ON      47.986300      -85.461400
# 103      Thunder Bay, Unorganized       ON      48.694200      -85.918800
#
#     NAICS 4 Sector Name (English)  NAICS 4 Code  ...  \
# 0                Metal ore mining          2122  ...
# 1                Metal ore mining          2122  ...
# 2                Metal ore mining          2122  ...
# 3                Metal ore mining          2122  ...
# 4                Metal ore mining          2122  ...
# ..                            ...           ...  ...
# 99               Metal ore mining          2122  ...
# 100              Metal ore mining          2122  ...
# 101              Metal ore mining          2122  ...
# 102              Metal ore mining          2122  ...
# 103              Metal ore mining          2122  ...
#
#                          Company_Name_NRCan  Mining_Processing_Type  \
# 0                                      None                    None
# 1                Agnico Eagle Mines Limited                (U., C.)
# 2                                      None                    None
# 3                Agnico Eagle Mines Limited                (P., C.)
# 4                Agnico Eagle Mines Limited                    (C.)
# ..                                      ...                     ...
# 99   Vale Newfoundland and Labrador Limited            (P., U., C.)
# 100               Victoria Gold Corporation                (P., C.)
# 101                 Wesdome Gold Mines Ltd.                (U., C.)
# 102                 Wesdome Gold Mines Ltd.                (U., C.)
# 103                Barrick Gold Corporation            (P., U., C.)
#
#                 Commodities  GHGE (ktCO2eq)   GHG ID  \
# 0                      None             NaN      NaN
# 1              Gold, silver           24.25  10617.0
# 2                      None           34.50  10681.0
# 3              Gold, silver          194.87  10669.0
# 4                      Gold          248.77  10587.0
# ..                      ...             ...      ...
# 99   Nickel, copper, cobalt          148.26  10570.0
# 100                    Gold           51.74  12459.0
# 101                    Gold             NaN      NaN
# 102                    Gold             NaN      NaN
# 103                    Gold           21.28  10857.0
#
#                                           Link1_MinCan  \
# 0                                                 None
# 1    http://www.geologyontario.mndm.gov.on.ca/mndmf...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 99                                                 NaN
# 100                                                NaN
# 101  https://miningdataonline.com/property/232/Eagl...
# 102  https://miningdataonline.com/property/232/Eagl...
# 103              https://www.mindat.org/loc-26366.html
#
#                                           Link2_MinCan  \
# 0                                                 None
# 1    https://publications.gc.ca/collections/Collect...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
#
#                       latitude_df4                  longitude_df4 Link3_MinCan
# 0    no coordinates matching found  no coordinates matching found         None
# 1                        48.130261                     -80.088542          NaN
# 2                        68.137186                    -106.612652          NaN
# 3                        48.129852                     -78.100285          NaN
# 4                           65.025                      -96.04889          NaN
# ..                             ...                            ...          ...
# 99                       56.331344                     -62.097057          NaN
# 100                        64.0322                      -135.8456          NaN
# 101                       47.98439                      -85.45937          NaN
# 102                       47.98439                      -85.45937          NaN
# 103                       48.69442                      -85.92069          NaN
#
# [104 rows x 32 columns]

# %%
manufacturing_df = merge_datasets_by_coordinates(
    recap_metal_manufacturing_df, ghg_facility_df_metal_manufacturing, nrcan_manufacturing_df, min_can,
    atol=0.1)
# Out:
# Match Percentage between df1 and df2: 53.94%
# Match Percentage between df1 and df3: 50.30%
# Match Percentage between df1 and df4: 8.48%

# %%
column_order = [
    "NPRI ID",
    "GHG ID",
    "City",
    "CSD",
    "Province",
    "Latitude_NPRI",
    "Longitude_NPRI",
    "NAICS 4 Sector Name (English)",
    "NAICS 4 Code",
    "NAICS 6 Sector Name (English)",
    "NAICS 6 Code",
    "Company_Name_NPRI",
    "Facility_Name_NPRI",
    "Air Emissions",
    "Water Releases",
    "Land Releases",
    "GHGE (ktCO2eq)",
    "Mining_Processing_Type",
    "Commodities",
    "Link1_MinCan",
    "Link2_MinCan",
    "Link3_MinCan"
]

# %%
mining_df = mining_df[[col for col in column_order if col in mining_df.columns]]
manufacturing_df = manufacturing_df[[col for col in column_order if col in manufacturing_df.columns]]

# %%
with pd.ExcelWriter("data/Mining_production_data/template_data_collection_from_npri.xlsx", engine='openpyxl') as writer:
    mining_df.to_excel(writer, sheet_name='metal_mining', index=False)
    manufacturing_df.to_excel(writer, sheet_name='metal_manufacturing', index=False)

# %%
mining_df['Company_Name_NPRI'].value_counts()
# Out:
# Company_Name_NPRI
# Vale Canada Limited                                   10
# Cameco Corporation                                     4
# Hudbay Minerals                                        4
# ArcelorMittal Exploitation Minière Canada s.e.n.c.     3
# Glencore Canada Corporation                            3
#                                                       ..
# Teck Metals Limited                                    1
# Vale Canada Ltd                                        1
# Vale Newfoundland and Labrador Limited                 1
# Victoria Gold Corp.                                    1
# Williams Operating Corporation                         1
# Name: count, Length: 72, dtype: int64

# %%
manufacturing_df['Company_Name_NPRI'].value_counts()
# Out:
# Company_Name_NPRI
# Rio Tinto Alcan Inc                            8
# ArcelorMittal Produits Longs Canada s.e.n.c    4
# EVRAZ Inc NA Canada                            4
# Glencore Canada Corporation                    3
# 5N Plus Inc.                                   3
#                                               ..
# Umicore Precious Metals Canada Inc.            1
# Valbruna ASW Inc.                              1
# Vale Canada Ltd                                1
# Vale Newfoundland and Labrador Limited         1
# Wabtec Foundry Ltd.                            1
# Name: count, Length: 133, dtype: int64

# %% [markdown]
# ## 2.3 Add SUT energy accounts

# %%
sut_df = pd.read_csv(r'data/Emissions_accounts/Raw_data/Mining industries, energy consumption by NAICS - 16100029-eng/16100029.csv')

# %%
sut_df
# Out:
#       REF_DATE     GEO           DGUID  \
# 0         2019  Canada  2021A000011124
# 1         2019  Canada  2021A000011124
# 2         2019  Canada  2021A000011124
# 3         2019  Canada  2021A000011124
# 4         2019  Canada  2021A000011124
# ...        ...     ...             ...
# 3667      2022  Canada  2021A000011124
# 3668      2022  Canada  2021A000011124
# 3669      2022  Canada  2021A000011124
# 3670      2022  Canada  2021A000011124
# 3671      2022  Canada  2021A000011124
#
#      North American Industry Classification System (NAICS)  \
# 0                               Metal ore mining [2122]
# 1                               Metal ore mining [2122]
# 2                               Metal ore mining [2122]
# 3                               Metal ore mining [2122]
# 4                               Metal ore mining [2122]
# ...                                                 ...
# 3667  Shale, clay and refractory mineral mining and ...
# 3668  Shale, clay and refractory mineral mining and ...
# 3669  Shale, clay and refractory mineral mining and ...
# 3670  Shale, clay and refractory mineral mining and ...
# 3671  Shale, clay and refractory mineral mining and ...
#
#                                          Energy types                   UOM  \
# 0       Total, energy expenses (thousands of dollars)  Thousands of dollars
# 1                   Coal, quantity purchased (tonnes)                Tonnes
# 2               Coal, expenses (thousands of dollars)  Thousands of dollars
# 3         Petroleum coke, quantity purchased (tonnes)                Tonnes
# 4     Petroleum coke, expenses (thousands of dollars)  Thousands of dollars
# ...                                               ...                   ...
# 3667         Wood, quantity purchased (metric tonnes)         Metric tonnes
# 3668            Wood, expenses (thousands of dollars)  Thousands of dollars
# 3669               Water, quantity purchased (litres)                Litres
# 3670           Water, expenses (thousands of dollars)  Thousands of dollars
# 3671           Other, expenses (thousands of dollars)  Thousands of dollars
#
#       UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE      VALUE  \
# 0        284         units          0  v1354185599      1.1.1  1929480.0
# 1        287         units          0  v1354185610      1.1.2   207878.0
# 2        284         units          0  v1354185621      1.1.3    35852.0
# 3        287         units          0  v1354185627      1.1.4        0.0
# 4        284         units          0  v1354185628      1.1.5        0.0
# ...      ...           ...        ...          ...        ...        ...
# 3667     214         units          0  v1354186268    1.27.30        0.0
# 3668     284         units          0  v1354186269    1.27.31        0.0
# 3669     203         units          0  v1354186270    1.27.32        NaN
# 3670     284         units          0  v1354186271    1.27.33        NaN
# 3671     284         units          0  v1354186272    1.27.34        0.0
#
#      STATUS  SYMBOL  TERMINATED  DECIMALS
# 0       NaN     NaN         NaN         0
# 1       NaN     NaN         NaN         0
# 2       NaN     NaN         NaN         0
# 3       NaN     NaN         NaN         0
# 4       NaN     NaN         NaN         0
# ...     ...     ...         ...       ...
# 3667    NaN     NaN         NaN         0
# 3668    NaN     NaN         NaN         0
# 3669      x     NaN         NaN         0
# 3670      x     NaN         NaN         0
# 3671    NaN     NaN         NaN         0
#
# [3672 rows x 16 columns]

# %%
def clean_sut(df, year=None, naics=None, units_to_exclude=None):
    # Drop specified columns
    columns_to_remove = ['DGUID', 'UOM_ID', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS', 'SCALAR_FACTOR']
    df_cleaned = df.drop(columns=columns_to_remove, errors='ignore')
    
    # Filter by year if specified
    if year is not None:
        df_cleaned = df_cleaned[df_cleaned['REF_DATE'] == year]
    
    # Filter by NAICS if specified
    if naics is not None:
        df_cleaned = df_cleaned[df_cleaned['North American Industry Classification System (NAICS)'] == naics]
    
    # Exclude specified units from the UOM column if provided
    if units_to_exclude is not None:
        df_cleaned = df_cleaned[~df_cleaned['UOM'].isin(units_to_exclude)]
        
    # Remove rows where VALUE is 0 or NaN
    df_cleaned = df_cleaned[df_cleaned['VALUE'].notna() & (df_cleaned['VALUE'] != 0)]
    
    df_cleaned.reset_index(drop=True, inplace=True)
        
    return df_cleaned

# %%
sut_df_cleaned = clean_sut(sut_df, year=2022, units_to_exclude=["Thousands of dollars"])
sut_df_cleaned
# Out:
#      REF_DATE     GEO North American Industry Classification System (NAICS)  \
# 0        2022  Canada                            Metal ore mining [2122]
# 1        2022  Canada                            Metal ore mining [2122]
# 2        2022  Canada                            Metal ore mining [2122]
# 3        2022  Canada                            Metal ore mining [2122]
# 4        2022  Canada                            Metal ore mining [2122]
# ..        ...     ...                                                ...
# 117      2022  Canada     Sand and gravel, mining and quarrying [212323]
# 118      2022  Canada     Sand and gravel, mining and quarrying [212323]
# 119      2022  Canada     Sand and gravel, mining and quarrying [212323]
# 120      2022  Canada  Shale, clay and refractory mineral mining and ...
# 121      2022  Canada  Shale, clay and refractory mineral mining and ...
#
#                                          Energy types           UOM  \
# 0                   Coal, quantity purchased (tonnes)        Tonnes
# 1      Natural gas, quantity purchased (cubic metres)  Cubic metres
# 2    Gasoline - aviation, quantity purchased (litres)        Litres
# 3       Gasoline - motor, quantity purchased (litres)        Litres
# 4            Diesel fuel, quantity purchased (litres)        Litres
# ..                                                ...           ...
# 117       Light Fuel Oil, quantity purchased (litres)        Litres
# 118       Heavy Fuel Oil, quantity purchased (litres)        Litres
# 119              Propane, quantity purchased (litres)        Litres
# 120          Diesel fuel, quantity purchased (litres)        Litres
# 121              Propane, quantity purchased (litres)        Litres
#
#            VALUE
# 0       179231.0
# 1    152461339.0
# 2     11834517.0
# 3     31567077.0
# 4    941997194.0
# ..           ...
# 117     160123.0
# 118     424742.0
# 119    1152653.0
# 120     577582.0
# 121    2306661.0
#
# [122 rows x 6 columns]

# %%
sut_df_cleaned['North American Industry Classification System (NAICS)'].value_counts()
# Out:
# North American Industry Classification System (NAICS)
# Metal ore mining [2122]                                                                                        10
# Sand, gravel, clay, and ceramic and refractory minerals mining and quarrying [21232]                            9
# Other non-metallic mineral mining and quarrying [21239]                                                         8
# Non-metallic mineral mining (excluding aggregates, clay and refractory mineral mining and quarrying) [2123]     8
# Aggregates, clay and refractory mineral mining and quarrying (excluding non-metallic mineral mining) [2123]     8
# Stone mining and quarrying [21231]                                                                              8
# Copper, nickel, lead and zinc ore mining [21223]                                                                7
# Copper-zinc ore mining [212233]                                                                                 7
# Limestone mining and quarrying [212315]                                                                         6
# Sand and gravel, mining and quarrying [212323]                                                                  6
# Gold and silver ore mining [21222]                                                                              5
# Iron ore mining [21221]                                                                                         5
# Nickel-copper ore mining [212232]                                                                               4
# All other non-metallic mineral mining and quarrying [212398]                                                    4
# Diamond mining [212392]                                                                                         3
# Other metal ore mining [21229]                                                                                  3
# Uranium ore mining [212291]                                                                                     3
# Potash mining [212396]                                                                                          3
# Sandstone mining and quarrying [212317]                                                                         3
# Peat extraction [212397]                                                                                        3
# Lead-zinc ore mining [212231]                                                                                   2
# Granite mining and quarrying [212314]                                                                           2
# All other metal ore mining [212299]                                                                             2
# Shale, clay and refractory mineral mining and quarrying [212326]                                                2
# Salt mining [212393]                                                                                            1
# Name: count, dtype: int64

# %%
def split_by_naics(df_cleaned):
    # Group the DataFrame by the 'NAICS' column
    naics_groups = df_cleaned.groupby('North American Industry Classification System (NAICS)')
    
    # Create a dictionary where keys are NAICS values and values are the corresponding DataFrames
    naics_dfs = {naics: group.reset_index(drop=True) for naics, group in naics_groups}
    
    return naics_dfs

# %%
# Apply the function to the cleaned DataFrame
naics_dfs = split_by_naics(sut_df_cleaned)

# Access a specific NAICS DataFrame
uranium_mining_df = naics_dfs['Uranium ore mining [212291]']

# %%
uranium_mining_df
# Out:
#    REF_DATE     GEO North American Industry Classification System (NAICS)  \
# 0      2022  Canada                        Uranium ore mining [212291]
# 1      2022  Canada                        Uranium ore mining [212291]
# 2      2022  Canada                        Uranium ore mining [212291]
#
#                                       Energy types             UOM  \
# 0         Diesel fuel, quantity purchased (litres)          Litres
# 1             Propane, quantity purchased (litres)          Litres
# 2  Electricity, quantity purchased (kilowatt-hour)  Kilowatt-hours
#
#          VALUE
# 0    2958363.0
# 1   29071811.0
# 2  305354512.0

# %% [markdown]
# # 3 - Normalize emissions per facility

# %%
df_production = pd.read_excel(r'../data/canada_site_specific_data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_production = pd.read_excel(r'../data/canada_site_specific_data.xlsx')
#
# File ~\anaconda3\envs\lca\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\anaconda3\envs\lca\lib\site-packages\pandas\io\excel\_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~\anaconda3\envs\lca\lib\site-packages\pandas\io\excel\_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~\anaconda3\envs\lca\lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: '../data/canada_site_specific_data.xlsx'

# %% [markdown]
# ## Example

# %%
npri_voisey = dfs_by_company_facility["Vale_Newfoundland_and_Labrador_Limited_Voisey's_Bay_Mine_Site"]
npri_voisey
# Out:
#      level_0  index  Year  NPRI ID                            Company Name  \
# 4         32   1070  2023     6093  Vale Newfoundland and Labrador Limited
# 11       100   1714  2023     6093  Vale Newfoundland and Labrador Limited
# 25       191   3009  2023     6093  Vale Newfoundland and Labrador Limited
# 39       258   3672  2023     6093  Vale Newfoundland and Labrador Limited
# 54       329   7468  2023     6093  Vale Newfoundland and Labrador Limited
# 61       391   7957  2023     6093  Vale Newfoundland and Labrador Limited
# 74       464   8340  2023     6093  Vale Newfoundland and Labrador Limited
# 87       541   9147  2023     6093  Vale Newfoundland and Labrador Limited
# 89       553   9702  2023     6093  Vale Newfoundland and Labrador Limited
# 91       571  10468  2023     6093  Vale Newfoundland and Labrador Limited
# 98       635  11861  2023     6093  Vale Newfoundland and Labrador Limited
# 113      717  12428  2023     6093  Vale Newfoundland and Labrador Limited
# 119      772  12858  2023     6093  Vale Newfoundland and Labrador Limited
# 124      802  13208  2023     6093  Vale Newfoundland and Labrador Limited
# 129      826  14546  2023     6093  Vale Newfoundland and Labrador Limited
# 151      940  15647  2023     6093  Vale Newfoundland and Labrador Limited
# 164      992  19390  2023     6093  Vale Newfoundland and Labrador Limited
# 166      998  19538  2023     6093  Vale Newfoundland and Labrador Limited
# 168     1013  19896  2023     6093  Vale Newfoundland and Labrador Limited
# 173     1068  20912  2023     6093  Vale Newfoundland and Labrador Limited
# 192     1169  26128  2023     6093  Vale Newfoundland and Labrador Limited
# 211     1264  31098  2023     6093  Vale Newfoundland and Labrador Limited
# 223     1313  31249  2023     6093  Vale Newfoundland and Labrador Limited
# 229     1346  46894  2023     6093  Vale Newfoundland and Labrador Limited
# 246     1469  53787  2023     6093  Vale Newfoundland and Labrador Limited
# 261     1555  57681  2023     6093  Vale Newfoundland and Labrador Limited
# 267     1597  58340  2023     6093  Vale Newfoundland and Labrador Limited
# 273     1638  63596  2023     6093  Vale Newfoundland and Labrador Limited
#
#               Facility Name                    City                       CSD  \
# 4    Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 11   Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 25   Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 39   Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 54   Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 61   Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 74   Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 87   Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 89   Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 91   Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 98   Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 113  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 119  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 124  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 129  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 151  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 164  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 166  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 168  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 173  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 192  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 211  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 223  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 229  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 246  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 261  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 267  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
# 273  Voisey's Bay Mine Site  Happy Valley-Goose Bay  Division No. 10, Subd. E
#
#     CA or CMA                                    Economic Region  ...  \
# 4              West Coast--Northern Peninsula--Labrador / Côt...  ...
# 11             West Coast--Northern Peninsula--Labrador / Côt...  ...
# 25             West Coast--Northern Peninsula--Labrador / Côt...  ...
# 39             West Coast--Northern Peninsula--Labrador / Côt...  ...
# 54             West Coast--Northern Peninsula--Labrador / Côt...  ...
# 61             West Coast--Northern Peninsula--Labrador / Côt...  ...
# 74             West Coast--Northern Peninsula--Labrador / Côt...  ...
# 87             West Coast--Northern Peninsula--Labrador / Côt...  ...
# 89             West Coast--Northern Peninsula--Labrador / Côt...  ...
# 91             West Coast--Northern Peninsula--Labrador / Côt...  ...
# 98             West Coast--Northern Peninsula--Labrador / Côt...  ...
# 113            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 119            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 124            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 129            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 151            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 164            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 166            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 168            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 173            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 192            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 211            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 223            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 229            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 246            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 261            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 267            West Coast--Northern Peninsula--Labrador / Côt...  ...
# 273            West Coast--Northern Peninsula--Labrador / Côt...  ...
#
#     Metal Recovery Inorganic Compound Recovery Acid or Base Recovery  \
# 4              NaN                         NaN                   NaN
# 11             NaN                         NaN                   NaN
# 25             NaN                         NaN                   NaN
# 39             NaN                         NaN                   NaN
# 54             NaN                         NaN                   NaN
# 61             NaN                         NaN                   NaN
# 74             NaN                         NaN                   NaN
# 87             NaN                         NaN                   NaN
# 89             NaN                         NaN                   NaN
# 91             NaN                         NaN                   NaN
# 98             NaN                         NaN                   NaN
# 113            NaN                         NaN                   NaN
# 119            NaN                         NaN                   NaN
# 124            NaN                         NaN                   NaN
# 129            NaN                         NaN                   NaN
# 151            NaN                         NaN                   NaN
# 164            NaN                         NaN                   NaN
# 166            NaN                         NaN                   NaN
# 168            NaN                         NaN                   NaN
# 173            NaN                         NaN                   NaN
# 192            NaN                         NaN                   NaN
# 211            NaN                         NaN                   NaN
# 223            NaN                         NaN                   NaN
# 229            NaN                         NaN                   NaN
# 246            NaN                         NaN                   NaN
# 261            NaN                         NaN                   NaN
# 267            NaN                         NaN                   NaN
# 273            NaN                         NaN                   NaN
#
#     Catalyst Recovery Pollution Abatement Residue Recovery Used Oil Recovery  \
# 4                 NaN                                  NaN               NaN
# 11                NaN                                  NaN               NaN
# 25                NaN                                  NaN               NaN
# 39                NaN                                  NaN               NaN
# 54                NaN                                  NaN               NaN
# 61                NaN                                  NaN               NaN
# 74                NaN                                  NaN               NaN
# 87                NaN                                  NaN               NaN
# 89                NaN                                  NaN               NaN
# 91                NaN                                  NaN               NaN
# 98                NaN                                  NaN               NaN
# 113               NaN                                  NaN               NaN
# 119               NaN                                  NaN               NaN
# 124               NaN                                  NaN               NaN
# 129               NaN                                  NaN               NaN
# 151               NaN                                  NaN               NaN
# 164               NaN                                  NaN               NaN
# 166               NaN                                  NaN               NaN
# 168               NaN                                  NaN               NaN
# 173               NaN                                  NaN               NaN
# 192               NaN                                  NaN               NaN
# 211               NaN                                  NaN               NaN
# 223               NaN                                  NaN               NaN
# 229               NaN                                  NaN               NaN
# 246               NaN                                  NaN               NaN
# 261               NaN                                  NaN               NaN
# 267               NaN                                  NaN               NaN
# 273               NaN                                  NaN               NaN
#
#      Other.2  Total.5  Total Releases, Disposals and Transfers for Recycling  \
# 4        NaN      NaN                                         384.221000
# 11       NaN      NaN                                        1421.578000
# 25       NaN      NaN                                        1604.145000
# 39       NaN      NaN                                         335.124000
# 54       NaN      NaN                                         563.493000
# 61       NaN      NaN                                      241743.578000
# 74       NaN      NaN                                        1237.842000
# 87       NaN      NaN                                           0.000000
# 89    56.975   56.975                                          56.975000
# 91       NaN      NaN                                           4.808000
# 98       NaN      NaN                                       73079.384500
# 113      NaN      NaN                                        1761.568000
# 119      NaN      NaN                                         104.226000
# 124      NaN      NaN                                         106.776000
# 129      NaN      NaN                                        4860.584000
# 151      NaN      NaN                                        3241.382000
# 164      NaN      NaN                                         136.966000
# 166      NaN      NaN                                          25.626000
# 168      NaN      NaN                                        2175.873150
# 173      NaN      NaN                                         845.291000
# 192      NaN      NaN                                         133.897000
# 211      NaN      NaN                                       23826.776000
# 223      NaN      NaN                                           2.397737
# 229      NaN      NaN                                           3.526000
# 246      NaN      NaN                                        3002.078000
# 261      NaN      NaN                                         200.242294
# 267      NaN      NaN                                          52.696000
# 273      NaN      NaN                                         204.440000
#
#                                                     EI
# 4                                              Ammonia
# 11                                             Arsenic
# 25                                             Cadmium
# 39                             Carbon monoxide, fossil
# 54                                            Chromium
# 61                                              Cobalt
# 74                                              Copper
# 87                                      No match found
# 89                                      No match found
# 91                                Benzene, hexachloro-
# 98                                                Lead
# 113                                          Manganese
# 119                                            Mercury
# 124                                           Methanol
# 129  Ni, Ni 2.3E+0%, Pt 2.5E-4%, Pd 7.3E-4%, Rh 2.0...
# 151                                    Nitrogen oxides
# 164                             Hydrocarbons, aromatic
# 166                                       Phenanthrene
# 168                                         Phosphorus
# 173                                     No match found
# 192                             Particulates, < 2.5 um
# 211                                           Selenium
# 223                                             Silver
# 229                                                NaN
# 246                                     No match found
# 261                                           Vanadium
# 267                                                NaN
# 273                                               Zinc
#
# [28 rows x 80 columns]

# %%
def allocate_emissions(
    df, production_data, metals, economic_values=None, method='mass',
    unit_column='Units', 
):
    """
    Updated function to exclude specific columns like 'EI' from conversion,
    while performing unit conversion, normalization, and allocation.
    """
    # Step 1: Trim the DataFrame to include only relevant columns
    start_col = 'Substance Name (English)'
    df = df.loc[:, start_col:].copy()

    # Step 2: Identify emission columns (exclude non-numeric columns like 'EI')
    start_col = 'Stack Emissions'
    end_col = 'Total Releases, Disposals and Transfers for Recycling'
    emission_columns = df.loc[:, start_col:end_col].select_dtypes(include='number').columns.tolist()

    # Step 3: Convert units to kg for emissions columns only
    conversion_factors = {'tonnes': 1000, 'kg': 1, 'grams': 0.001, 'g TEQ': 0.001}
    if unit_column in df.columns:
        for unit, factor in conversion_factors.items():
            mask = df[unit_column] == unit
            df.loc[mask, emission_columns] = df.loc[mask, emission_columns] * factor
        df[unit_column] = 'kg'

    # Step 4: Normalize emissions per kg of total production
    total_production = sum(production_data.values())
    for col in emission_columns:
        df[f'{col}_per_kg_Total'] = df[col] / total_production

    # Step 5: Allocate emissions (mass or economic)
    allocation_factors = {}
    for metal, production in production_data.items():
        if method == 'mass':
            allocation_factors[metal] = production / total_production
        elif method == 'economic':
            total_economic_value = sum(production_data[m] * economic_values[m] for m in metals)
            allocation_factors[metal] = (production * economic_values[metal]) / total_economic_value
        else:
            raise ValueError("Invalid method. Use 'mass' or 'economic'.")

    for col in emission_columns:
        for metal in metals:
            df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]

    return df

# %%
production_data = {'Nickel': 50000000, 'Copper': 32000000}  # kg of nickel and copper metal in concentrate
economic_values = {'Nickel': 13800, 'Copper': 6160}  # unit value in 2019 $/t given by USGS
metals = ['Nickel', 'Copper']

# %%
mass_df = allocate_emissions(
    npri_voisey, production_data, metals, economic_values=economic_values, method='mass', 
    unit_column='Units'
)

economic_df = allocate_emissions(
    npri_voisey, production_data, metals, economic_values=economic_values, method='economic', 
    unit_column='Units'
)
# Out:
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]
# C:\Users\mp_ma\AppData\Local\Temp\ipykernel_6360\1067121282.py:44: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'{col}_per_kg_{metal}'] = df[f'{col}_per_kg_Total'] * allocation_factors[metal]

# %%
def organize_emissions_data(df, metals):
    """
    Organize the emissions data into a clean format with desired columns.
    """
    # Define category mapping
    category_mapping = {
        'Air Emissions': ['Stack Emissions', 'Storage / Handling', 'Fugitive Emissions', 'Spills', 'Other', 'Total'],
        'Water Releases': ['Direct Discharge', 'Spills', 'Leaks', 'Total'],
        'Land Releases': ['Spills', 'Leaks', 'Other', 'Total'],
        'Total Releases': ['Total Releases (Excluding Road Dust)', 'Road Dust Emissions', 'Total Releases Including Road Dust'],
        'On-Site Disposal': ['Land Fill', 'Land Treatment', 'Underground Injection', 'Tailings', 'Waste Rock', 'Total On-Site'],
        'Off-Site Disposal': ['Land Fill', 'Land Treatment', 'Underground Injection', 'Storage', 'Tailings', 'Waste Rock', 'Total Off-Site'],
        'Transfers for Recycling': ['Energy Recovery', 'Metal Recovery', 'Other', 'Total']
    }

    # Prepare rows for clean output
    rows = []
    for category, columns in category_mapping.items():
        for col in columns:
            total_col = f"{col}_per_kg_Total"
            metal_cols = [f"{col}_per_kg_{metal}" for metal in metals]

            if total_col in df.columns:
                for _, row in df.iterrows():
                    row_data = {
                        'Type': category,
                        'Category': col,
                        'Substance Name (English)': row['Substance Name (English)'],
                        'Ecoinvent Name': row['EI'] if 'EI' in df.columns else 'Unknown',
                        'Unit': row['Units'],
                        'Total Emissions (per kg)': row[total_col],
                    }
                    for metal, metal_col in zip(metals, metal_cols):
                        row_data[f'{metal} Emissions (per kg)'] = row[metal_col] if metal_col in df.columns else 0
                    rows.append(row_data)

    # Convert to DataFrame
    result_df = pd.DataFrame(rows)

    return result_df

# %%
mass_df = organize_emissions_data(mass_df, metals)
economic_df = organize_emissions_data(economic_df, metals)

# %%
with pd.ExcelWriter('allocation.xlsx', engine='xlsxwriter') as writer:
    mass_df.to_excel(writer, sheet_name='mass', index=False)
    economic_df.to_excel(writer, sheet_name='eco', index=False)

# %% [markdown]
# # 4 - Create national consumption markets based on production data
